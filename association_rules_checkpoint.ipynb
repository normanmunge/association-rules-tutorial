# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
toy_dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

        ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

        ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

        ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

      ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
# Transform the code using Onehotencoding
te=TransactionEncoder()

te_dataset=te.fit(toy_dataset).transform(toy_dataset)

# %%
te_dataset
# Out:
# array([[False, False,  True, False, False,  True, False,  True, False,
#          True,  True, False],
#        [False, False,  True, False, False,  True, False, False, False,
#          True,  True,  True],
#        [ True, False, False,  True, False,  True,  True,  True, False,
#         False, False, False],
#        [ True,  True,  True,  True,  True, False, False,  True, False,
#         False, False, False],
#        [False,  True, False, False, False,  True, False,  True,  True,
#          True, False, False]])

# %%
# Create a dataframe
toy_df = pd.DataFrame(te_dataset, columns=te.columns_)

# %%
toy_df.head()
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
# Use apriori model with 60% support
frequent_itemsets = apriori(toy_df, min_support=0.6, use_colnames=True)

# %%
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Pants, Skirt)

# %%
# Extract rules from frequent itemsets
# Confidence rule
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate items
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  0.9375     -0.04         0.8          -0.25
# 1        0.75  0.9375     -0.04         0.8          -0.25
# 2        0.75  1.2500      0.12         1.6           1.00
# 3        1.00  1.2500      0.12         inf           0.50

# %% [markdown]
# * The confidence metrics checks through the probability of purchasing item Y after purchasing item X
# * In this case it chekcs through scarfs, pants and skirts which have a 0.7+ probability of being purchased together

# %%
# Associate based on lift
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction  zhangs_metric
# 0         1.0  1.25      0.12         inf            0.5

# %% [markdown]
# The lift of pants and skirts is 1.25 meaning that when purchasing pants it's highly likely that a customer will also get skirts
